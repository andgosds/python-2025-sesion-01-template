# %% [markdown]
# Lista.NombreMétodo(Parámetros)
#
# sort
#
# reverse
#
# count
#
# index
#
# extend
#
# clear
#
# append
#
# insert
#
# remove
#
# pop

# %% [markdown]
# ## Diccionarios

# %% [markdown]
# Diccionario.NombreMétodo(Parámetros)

# %% [markdown]
# copy
#
# clear
#
# pop
#
# popitem
#
# get
#
# update
#
# setdefault
#
# items
#
# keys
#
# values
